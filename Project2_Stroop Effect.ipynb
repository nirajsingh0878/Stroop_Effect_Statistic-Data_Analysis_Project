# %% [markdown]
# # Test a Perceptual Phenomenon - STROOP EFFECT
#
# ## Background Information
#
# In a Stroop task, participants are presented with a list of words, with each word displayed in a color of ink. The participant’s task is to say out loud the color of the ink in which the word is printed. The task has two conditions: a congruent words condition, and an incongruent words condition. In the congruent words condition, the words being displayed are color words whose names match the colors in which they are printed: for example RED, BLUE. In the incongruent words condition, the words displayed are color words whose names do not match the colors in which they are printed: for example PURPLE, ORANGE. In each case, we measure the time it takes to name the ink colors in equally-sized lists. Each participant will go through and record a time from each condition.

# %% [markdown]
# **Questions For Investigation**
#
# 1. What is our independent variable? What is our dependent variable?
#
# 2. What is an appropriate set of hypotheses for this task? What kind of statistical test do you expect to perform? Justify your choices.
#
#     Now it’s your chance to try out the Stroop task for yourself. Go to this link, which has a Java-based applet for performing the Stroop task. Record the times that you received on the task (you do not need to submit your times to the site.) Now, download this dataset which contains results from a number of participants in the task. Each row of the dataset contains the performance for one participant, with the first number their results on the congruent task and the second number their performance on the incongruent task.
#
# 3. Report some descriptive statistics regarding this dataset. Include at least one measure of central tendency and at least one measure of variability.
#
# 4. Provide one or two visualizations that show the distribution of the sample data. Write one or two sentences noting what you observe about the plot or plots.
#
# 5. Now, perform the statistical test and report your results. What is your confidence level and your critical statistic value?      Do you reject the null hypothesis or fail to reject it? Come to a conclusion in terms of the experiment task. Did the results match up with your expectations?
#
# 6. What do you think is responsible for the effects observed? Can you think of an alternative or similar task that would result in a similar effect?

# %% [markdown]
# **Question 1** : What is our independent variable? What is our dependent variable?
#
# **Answer** :
# - Dependent and Independent Variables -> An independent variable, sometimes called an experimental or predictor variable, is a variable that is being manipulated in an experiment in order to observe the effect on a dependent variable, sometimes called an outcome variable.
# - The dependent variable is simply that, a variable that is dependent on an independent variable(s).
# - Dependent variable is the one we measure through survey,experiment ,interview.
# - So here Stroop effect,we are measuring time of answering the color name's here Overall guessing time of colour of ink is Dependent And overall answering time of colour of ink is depending upon the condition of way the words and ink of word used it can be congruent and incongruent.Here conguent and incongruent way of providing ink colour of words is indepenndent.
# - Dependent variable - time taken by participant go through and record a time from each condition.
#   Independent variable - conguent and incongruent way of providing ink colour of words is indepenndent

# %% [markdown]
# **Question 2** :What is an appropriate set of hypotheses for this task? What kind of statistical test do you expect to perform? Justify your choices.
#
# **Answer** : There are two statistical hypothesis: 1. Null Hypothesis 2. Alternate Hypothesis
# - Null Hypothesis : Incongruent and Congruent words condition have the same effect on participant time for saying colours of the                     words.
#
# - Null Hypothesis ($H_0$):
#
# <center>$H_0$ : $u_c = u_I$</center>
#
# - Alternate Hypothesis($H_A$) :
#
# <center>$H_A$ : $u_c < u_I$</center>
#
# <center>$H_A$ : $u_c > u_I$</center>
#
# <center>$H_A$ : $u_c \ne u_I$</center>
#
# - Alternate Hypothesis : Incongruent and Congruent words condition have the does not have a same effect on participant time for                          saying colours of the words beacause the different effect either time recorded increase or decrease                              significalty.
#
# #### For Statistical test we have two options:1. t test 2. z test
#
# -  We are choosing **t Test** over **z test** because here:
#
#    1. z test work when we have population mean and population standard deviation and we dont have both.
#    2. We have sample size **below 30**.
#    3. We have a **unknown population standard deviation**.
#
# -  Here we are performing two test based on two condition(Congruent and Incongruent) on a same participant.
#
# -  we are Assuming that distrubution of data is Normal distribution which form symmetrical bell shape.
# -  T -Test,Level of significance (α level) : 0.05(5%)
# -  Its Paired Two Tailed t-Test

# %% [markdown]
# **Question 3** :Report some descriptive statistics regarding this dataset. Include at least one measure of central tendency and at least one measure of variability.
#
# **Answer** :
#
# **Descriptive Statistics**
#
# |Congruent	|Incongruent|
# | ------------- |:-------------:|
# |8.63	|15.687|
# |8.987	|17.394|
# |9.401	|20.762|
# |9.564	|21.214|
# |10.639	|20.429|
# |11.344	|17.425|
# |12.079	|19.278|
# |12.13	|22.158|
# |12.238	|20.878|
# |12.369	|34.288|
# |12.944	|23.894|
# |14.233	|17.96|
# |14.48	|26.282|
# |14.669	|22.803|
# |14.692	|24.572|
# |15.073|	17.51|
# |15.298	|18.644|
# |16.004	|21.157|
# |16.791	|18.741|
# |16.929|	20.33|
# |18.2|	35.255|
# |18.495	|25.139|
# |19.71	|22.058|
# |22.328	|24.524|
#
# Measure Of Central Tendency
#
# | Measure of Central Tendency      | Congruent           |  Incongruent |
# | ------------- |:-------------:| -----:|
# |   Median      | 14.3565 | 21.0175 |
# | Mean      | 14.051125      |  22.01591667 |
# | Mode |    #N/A  |   #N/A |
#
# Measure of Variability
#
# | Measure of Variability      | Congruent           |  Incongruent |
# | ------------- |:-------------:| -----:|
# |   Range      | 13.698 | 19.568 |
# | Mean Deviation      | 2.853114583     |  3.401152778 |
# | Standard Deviation |    3.559357958  |   4.797057122 |

# %% [markdown]
# **Question 4** :Provide one or two visualizations that show the distribution of the sample data. Write one or two sentences noting what you observe about the plot or plots.
#
# **Answer** :
# Boxplot of Congruent and Incongruent Observation:
# -  There is huge diffrence between congruent and Incongruent median,upper and lower limit.
# -  Boxplot clearly shows how much indpendent variable (congruent and incongruent) depenedent upon the time of eac condition
#
# <img src="boxplot_Stroop.png">
#
# Comparision Barplot of Congruent and Incongruent Observation:
# -  Congruent make participant take significantly less time compared to Incongruent.
# <img src="chart.png">

# %% [markdown]
# **Question 5** :Perform the statistical test and report your results. What is your confidence level and your critical statistic value? Do you reject the null hypothesis or fail to reject it? Come to a conclusion in terms of the experiment task. Did the results match up with your expectations?
#
# **Answer** :
#
# **standard deviation** : 4.86482691
#
# **t statistics** : -8.020706945
#
# **Confident Interval** : (-10.01936791,-5.910215421))
#
# **t Critical** : +-2.069(0.05 %)     **DF = 23**
#
#  **The two-tailed P value is less than 0.0001
#    By conventional criteria, this difference is considered to be extremely statistically significant.**
#
# So We Reject Null Hypotheisis
#
#
# Result matched with our 95% confident internal
# Yes.Conguent techinique help people to perform better compared to Incongruent.
# yes.
#
# **Conclusion**: It matched with my expectaion because colour name with colour ink (congruent) technique make it easy and fast to guess.

# %% [markdown]
# **Question 6** :What do you think is responsible for the effects observed? Can you think of an alternative or similar task that would result in a similar effect?
#
# **Answer** :
#
# The words themselves have a strong influence over your ability to say the color. The interference between the different information (what the words say and the color of the words) your brain receives causes a problem. There are two theories that may explain the Stroop effect:
#
# Speed of Processing Theory: the interference occurs because words are read faster than colors are named.
# Selective Attention Theory: the interference occurs because naming colors requires more attention than reading words.
#
# **Alternative or Similar Task**
# -  Turn the words upside down or rotate them 90 degrees.
# - Compare long words to short words.
# -  Turn the words "inside out."

# %% [markdown]
# **References**:
#
# http://www.psychology.emory.edu/clinical/bliwise/Tutorials/TOM/meanstests/assump.html
#
# http://www2.psychology.uiowa.edu/faculty/mordkoff/GradStats/part%201/I.07%20normal.pdf
#
# https://statistics.laerd.com/statistical-guides/types-of-variable.php
#
# https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#tables
#
# https://en.wikipedia.org/wiki/Stroop_effect
#
# https://matplotlib.org/examples/pylab_examples/boxplot_demo.html
#
# https://www.graphpad.com/quickcalcs/pValue2/
#
# https://matplotlib.org/examples/pylab_examples/boxplot_demo.html
#
# http://www.statisticshowto.com/probability-and-statistics/hypothesis-testing/t-score-vs-z-score/
#
# https://faculty.washington.edu/chudler/words.html
#
#
# **Books**
#
# ##### Schaum's Outline : Probability and Statistics 3rd Edition By Murray R.Spigel Larry J.Stephens
